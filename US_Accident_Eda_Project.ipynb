# %% [markdown]
# Project:  US Accidents EDA by kevin

# %% [markdown]
# Description
# This is a countrywide car accident dataset that covers 49 states of the USA. The accident data were collected from February 2016 to March 2023, using multiple APIs that provide streaming traffic incident (or event) data. These APIs broadcast traffic data captured by various entities, including the US and state departments of transportation, law enforcement agencies, traffic cameras, and traffic sensors within the road networks. The dataset currently contains approximately 7.7 million accident records. For more information about this dataset, please visit here.7728394 rows × 46 columns
#
# AcknedgdgemenThis was inspired/adapted from Jovian, but purely done for learning purposes. This was a individual work , not cloned or forged . Thank youtems, AC
#
#
#
#
#
# -Are there more accidents in warmer or colder areas?
#
# -Which 5 states have the highest number of accidents? How about per capita? # -Does New York show up in the data? If yes, why is the count lower if this the most populated city.
#
# -Among the top 100 cities in number of accidents, which states do they belong to most frequently.
#
# -What time of the day are accidents most frequent in? - A
#
# -Which days of the week have the most accidents?
#
# -Which months have the most accidents?
#
# -What is the trend of accidents year over year (decreasing/increasing?)
#
# When is accidents per unit of traffic the highest.M, 2019.

# %%
import  pandas as  PD
import numpy

df = PD.read_csv("C:/Users/kevin/OneDrive/Desktop/SCIENTIST/EDA_Projects_/US_Accidents_March23.csv/US_Accidents_March23.csv")

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %% [markdown]
# open

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df)
# Out:
# 7728394

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
#15 numeric data, rest are dates, etc

newdf = df.select_dtypes(include=numerics)
len(newdf.columns)
# Out:
# 13

# %%
#missing values . false means there is no misising values
#True if mising
df.isna()
# Out:
#             ID  Source  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  \
# 0        False   False     False       False     False      False      False
# 1        False   False     False       False     False      False      False
# 2        False   False     False       False     False      False      False
# 3        False   False     False       False     False      False      False
# 4        False   False     False       False     False      False      False
# ...        ...     ...       ...         ...       ...        ...        ...
# 7728389  False   False     False       False     False      False      False
# 7728390  False   False     False       False     False      False      False
# 7728391  False   False     False       False     False      False      False
# 7728392  False   False     False       False     False      False      False
# 7728393  False   False     False       False     False      False      False
#
# ...

# %%
df.isna().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False)  / len(df)
missing_percentages
#Ascending
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# Traffic_Signal           0.000000e+00
# Roundabout               0.000000e+00
# Station                  0.000000e+00
# ...

# %%
missing_percentages.plot(kind='barh')
# Out:
# <Axes: >

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ### cities column analysis

# %% [markdown]
# Exploratory Analysis and Visualization
# Columns we'll analyze:
#
# ### City

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accidents = df.City.value_counts()
cities_by_accidents
# Out:
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 13678, dtype: int64

# %%
cities_by_accidents[:20].plot(kind  = 'barh')
# Out:
# <Axes: >

# %% [markdown]
# -Are there more accidents in warmer or colder areas?
#
# -Which 5 states have the highest number of accidents? How about per capita?
# #
# -Does New York show up in the data? If yes, why is the count lower if this the most populated city.
#
# -Among the top 100 cities in number of accidents, which states do they belong to most frequently.
#
# -What time of the day are accidents most frequent in? - A
#
# -Which days of the week have the most accidents?
#
# -Which months have the most accidents?
#
# -What is the trend of accidents year over year (decreasing/increasing?)
#
# - When is accidents per unit of traffic the highest.

# %%
#seaborn histogram

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.histplot(cities_by_accidents)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.distplot(cities_by_accidents)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\1368120759.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cities_by_accidents)
# <Axes: xlabel='City', ylabel='Density'>

# %%
high_accident_cities = cities_by_accidents[cities_by_accidents >= 1000]
low_accident_cities = cities_by_accidents[cities_by_accidents < 1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.08904159660793917

# %%
#Insights 
#no data for newyork
#less than 5% have yearly accidents

# %%
sns.distplot(high_accident_cities)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\2843252471.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_accident_cities)
# <Axes: xlabel='City', ylabel='Density'>

# %%
sns.distplot(low_accident_cities)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\469555131.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(low_accident_cities)
# <Axes: xlabel='City', ylabel='Density'>

# %%
sns.histplot(low_accident_cities, log_scale=True)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %%
sns.histplot(cities_by_accidents, log_scale=True)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %% [markdown]
# ##### No data from New York
# ##### The number of accidents per city decreases exponentially
# ##### Less than 5% of cities have more than 1000 yearly accidents.
# ##### Over 1200 cities have reported just one accident (need to investigate)

# %% [markdown]
# #### new column
# ##   start time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 05:46:00'

# %% [markdown]
# Are there more accidents in warmer or colder areas?
# Which 5 states have the highest number of accidents? How about per capita?
# Does New York show up in the data? If yes, why is the count lower if this the most populated city.
# Among the top 100 cities in number of accidents, which states do they belong to most frequently.
# What time of the day are accidents most frequent in? - ANSWERED
# Which days of the week have the most accidents?
# Which months have the most accidents?
# What is the trend of accidents year over year (decreasing/increasing?)
# When is accidents per unit of traffic the highest.

# %%
import pandas as pd
df.Start_Time = pd.to_datetime(df.Start_Time)


sns.distplot(df.Start_Time.dt.hour, bins=24 ,kde=False)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\2834115093.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24 ,kde=False)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# A high percentage of accidents occur between 6 am to 10 am (probably people in a hurry to get to work)
# Next higest percentage is 3 pm to 6 pm.- Figure out how to show percentages  Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\308908771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\362819596.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\3630331899.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# On Sundays, the peak occurs between 10 am and 3 pm, unlike weekdays

# %% [markdown]
# Can you explain the month-wise trend of accidents?
#
# Much data is missing for 2016. Maybe even 2017.
# There seems to be some issue with the Bing data

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]
sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\4268565558.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Source'>

# %% [markdown]
# - Consider excluding Bing data, seems to have issues.
# - ### Start Latitude & Longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
# !pip install folium

import folium
# Out:
# ...
#    ---------------------------------------- 0.0/97.0 kB ? eta -:--:--
#    ---------------------------------------- 97.0/97.0 kB 5.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/56.3 kB ? eta -:--:--
#    ---------------------------------------- 56.3/56.3 kB ? eta 0:00:00
# ...

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (39.865147, -84.058723)

# %%
for x in df[['Start_Lat', 'Start_Lng']].sample(100).iteritems():
    print(x[1])
# Out:
# 6203191    29.671979
# 4038093    42.378673
# 2129996    41.778690
# 1726257    32.653088
# 5836040    38.878662
#              ...
# 6613619    43.207133
# 6295321    33.885025
# 2385170    28.672899
# 886153     26.546551
# 5977773    28.332206
# Name: Start_Lat, Length: 100, dtype: float64
# 6203191    -95.570262
# 4038093    -83.234416
# 2129996    -72.697792
# 1726257   -117.069565
# 5836040    -77.260351
#               ...
# 6613619    -75.449984
# 6295321    -80.348197
# 2385170    -81.488808
# 886153     -81.846771
# 5977773    -81.568004
# Name: Start_Lng, Length: 100, dtype: float64
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\1934753555.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for x in df[['Start_Lat', 'Start_Lng']].sample(100).iteritems():

# %%
zip(list(df.Start_Lat), list(df.Start_Lng))

# %%
map = folium.Map()
marker = folium.Marker((lat, lon))
marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for x in df[['Start_Lat', 'Start_Lng']].sample(100).iteritems():
    print(x[1])
# Out:
# 6915362    37.278467
# 284762     32.881050
# 7670579    45.515570
# 2527776    33.501274
# 4263982    32.872370
#              ...
# 357253     26.627878
# 7290640    44.971750
# 5979255    41.686939
# 759887     39.297951
# 4487739    39.231251
# Name: Start_Lat, Length: 100, dtype: float64
# 6915362   -121.864138
# 284762     -96.894279
# 7670579   -122.798310
# 2527776    -81.875458
# 4263982    -83.661071
#               ...
# 357253     -80.067314
# 7290640    -93.380840
# 5979255    -91.511671
# 759887    -121.373466
# 4487739    -76.692301
# Name: Start_Lng, Length: 100, dtype: float64
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18988\1934753555.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for x in df[['Start_Lat', 'Start_Lng']].sample(100).iteritems():

# %%
from folium.plugins import HeatMap
sample_df = df.sample(int(0.001 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Summary and Conclusion
#
#
# Insights:
# - No data from New York
# - The number of accidents per city decreases exponentially
# - Less than 5% of cities have more than 1000 yearly accidents.
# - Over 1200 cities have reported just one accident (need to investigate)
